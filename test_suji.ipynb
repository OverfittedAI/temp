# %%
print("hello world")
# Out:
# hello world

# %%
print("hello world")
# Out:
# hello world

# %%
print("hello world")
# Out:
# hello world

# %%
print("hello world")
# Out:
# hello world

# %%
print("hello world")
# Out:
# hello world
